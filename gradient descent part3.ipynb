# %%
from matplotlib import pyplot as plt
x=-2
X=[]
J=[]
while(x<=5):
    j=((1/4)*pow(x,4))-((4/3)*pow(x,3))+((3/2)*pow(x,2))
    J.append(j)
    X.append(x)
    x+=0.1
    
plt.plot(X,J)
plt.xlabel("x")
plt.ylabel("j")
plt.show()
