# %%
from matplotlib import pyplot as plt
X=[-1,0.2,0.9,4]

for x in X:
    label="iteration(x="
    label=label+str(x)+")"
    func=(pow(x,3)-(4*pow(x,2))+3*x)
    itr=1
    lr=0.1
    t1=[]
    I=[]
    I.append(itr)
    t1.append(x)
    J=[]
    j=((1/4)*pow(x,4))-((4/3)*pow(x,3))+((3/2)*pow(x,2))
    J.append(j)
    while itr!=100:
        x=x-(lr*func)
        j=((1/4)*pow(x,4))-((4/3)*pow(x,3))+((3/2)*pow(x,2))
        func=(pow(x,3)-(4*pow(x,2))+3*x)
        t1.append(x)
        J.append(j)
        itr+=1
        I.append(itr)
    print("Final value of x",x)    
    print("Final value of j",j)
    plt.plot(I,J)
    plt.xlabel(label)
    plt.ylabel("j")
    plt.scatter(x,j,s=9,color='red')
    plt.grid()
    plt.show()
# Out:
# Final value of x -9.301997203713792e-17
# Final value of j 1.2979072796684882e-32
# Final value of x 1.4108710409455072e-16
# Final value of j 2.985835641267988e-32
# Final value of x 3.396037168015253e-14
# Final value of j 1.7299602669811068e-27
# Final value of x 3.0
# Final value of j -2.25
